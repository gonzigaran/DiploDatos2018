# %% [markdown]
# ### LABORATORIO

# %% [markdown]
# en el informe describir el dataset o los aspectos relevantes del mismo que se utilizarán durante el laboratorio.
# Es importante especificar por qué seleccionaron esos datos y qué tipo de información esperan extraer

# %%
# %matplotlib inline
import pandas as pd
import copy
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
#import corrplot

# %%
dataset = pd.read_csv('/home/vanessa/Diplomatura/T_P/recursos-humanos-cyt.csv')

# %%
dataset[:3]
# Out:
#    persona_id  provincia_id provincia max_nivel_educativo_desc     genero  \
# 0           1           2.0      CABA                Sin datos  masculino
# 1           5           2.0      CABA                Doctorado   femenino
# 2           7           2.0      CABA            Postdoctorado  masculino
#
#   edad_desc   tipo_personal             gran_area_formacion  \
# 0     40-49  becario de i+d                       sin datos
# 1     50-59    investigador    ciencias naturales y exactas
# 2     30-39  becario de i+d  ciencias médicas y de la salud
#
#                             tipo_organizacion_desc  \
# 0  Organismo gubernamental de ciencia y tecnología
# 1    Universidad o instituto universitario estatal
# 2  Organismo gubernamental de ciencia y tecnología
#
#             categoria_CONICET  categoria_incentivos_id
# 0       Otro personal Conicet                      NaN
# 1  Investigador independiente                      3.0
# 2      Investigador asistente                      NaN

# %%
import seaborn as sns
import matplotlib
matplotlib.rcParams['figure.figsize'] = 10, 8
ax = sns.countplot(x="tipo_organizacion_desc", data=dataset)
ax.set_xticklabels(ax.get_xticklabels(), rotation=70, ha="right")
# Out:
# [Text(0,0,'Organismo gubernamental de ciencia y tecnología'),
#  Text(0,0,'Universidad o instituto universitario estatal'),
#  Text(0,0,'Entidad administrativa de gobierno'),
#  Text(0,0,'OCT-Universidad'),
#  Text(0,0,'Entidad sin fines de lucro'),
#  Text(0,0,'Otras dependencias conjuntas'),
#  Text(0,0,'Universidad o instituto universitario privado'),
#  Text(0,0,'SIN DATOS'),
#  Text(0,0,'Empresa'),
#  Text(0,0,'Otra institución educativa no universitaria'),
#  Text(0,0,'Entidad internacional'),
#  Text(0,0,'Establecimiento asistencial de salud')]

# %%
dataset.edad_desc.value_counts()
# Out:
# 30-39          17602
# 40-49          14001
# 50-59          12585
# 60 y más        7204
# Menor de 30     4841
# Name: edad_desc, dtype: int64

# %%
dataset.edad_desc.index
# Out:
# RangeIndex(start=0, stop=56233, step=1)

# %%
fdps = dataset.edad_dec.value_counts(normalize=True).sort_index()
fdps
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-34e0fbee1a1e> in <module>()
# ----> 1 fdps = dataset.edad_dec.value_counts(normalize=True).sort_index()
#       2 fdps
#
# ~/miniconda3/envs/diplodatos-ayv/lib/python3.5/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'edad_dec'
