# %% [markdown]
# <center>
# <h4>Diplomatura AACSyA 2018 - FaMAF - UNC</h4>
# <h3>Análisis y visualización de datos</h3>
# </center>
#
# # Tarea integradora - Parte 1
#
# En esta notebook presentamos una serie de ejercicios para trabajar con variables aleatorias discretas, tanto númericas como cátegoricas, ejemplificando los conceptos de probabilidad explicados en clase. Lo primero es determinar si todas las librerías están correctamente instaladas.

# %%
# %matplotlib notebook
# %matplotlib inline
import pandas
import numpy
import seaborn

# %%
seaborn.set_style('whitegrid')
seaborn.set_context('talk')

# %% [markdown]
# ## Cargar el dataset en un dataframe de pandas
#
# Los dataframes son tablas con un montón de operaciones ya programadas. Prácticamente todas las funciones de SQL se pueden realizar en pandas con pocas líneas. Además de eso, tiene funciones para leer y escribir archivos en numerosos formatos.
#
# Ahora leemos directamente el archivo .csv

# %%
dataset = pandas.read_csv('https://cs.famaf.unc.edu.ar/~mteruel/datasets/diplodatos/violencia-institucional-2018-01.csv',
                          encoding='utf8')

# %%
dataset[:3]
# Out:
#      area    organismo_origen  via_acceso      año     provincia  \
# 0  DNPCVI  SECRETARIA DE DDHH  Telefónica  2017,00  Buenos Aires
# 1  DNPCVI  SECRETARIA DE DDHH  Telefónica  2017,00  Buenos Aires
# 2  DNPCVI  SECRETARIA DE DDHH  Telefónica  2017,00  Buenos Aires
#
#                    contexto                                  contexto1  \
# 0  Situaciones de Detención  Penal / Complejo Penitenciario PROVINCIAL
# 1  Situaciones de Detención  Penal / Complejo Penitenciario PROVINCIAL
# 2  Situaciones de Detención  Penal / Complejo Penitenciario PROVINCIAL
#
#   circunstancia                                        alojamiento  \
# 0           NaN                                                NaN
# 1           NaN  Malas condiciones de alojamiento (higiene), Hu...
# 2           NaN         Malas condiciones de alojamiento (higiene)
#
#   violencia_fisica violencia_psiquica violencia_genero  \
# 0              NaN                NaN              NaN
# 1              NaN                NaN              NaN
# 2              NaN                NaN              NaN
#
#                      violencia_salud  resumen_hecho  \
# 0  Denegación acceso atención médica            NaN
# 1  Denegación acceso atención médica            NaN
# 2                                NaN            NaN
#
#              descripcion_institucion         establecimiento  Unnamed: 16
# 0  Servicio Penitenciario Provincial         UPP Nº 13 Junin          NaN
# 1  Servicio Penitenciario Provincial      UPP Nº 13 DE JUNIN          NaN
# 2  Servicio Penitenciario Provincial  UPP Nº 36 de Magdalena          NaN

# %% [markdown]
# Los valores para los años no tienen un formato consistente en todas las filas, por lo que los procesaremos antes de comenzar. Los valores de año faltantes son reemplazados por NaN, y como la representación de enteros de numpy no soporta este tipo de valores, convertiremos cada año a tipo numpy.float. Otras decisiones pueden ser tomadas en este punto, como reemplazar los valores faltantes por 0 o elminarlos del dataset, dependiendo del tipo de datos que se requiera.
#
# También cambiaremos el nombre de la columna año, ya que el caracter ñ no permite utilizar el syntax sugar de pandas donde se obtienen los valores de la columna con la sintáxis de llamar a un método.

# %%
import six
def convert_to_int(row):
    try:
        return float(row)
    except ValueError:
        if isinstance(row, six.string_types):
            return float(row.split(',')[0])
        return row

dataset.loc[:,'year'] = dataset[u'año'].apply(convert_to_int)
# Se podrían también decodicar los nombres de provincias
# dataset.loc[:,'provincia'] = dataset.provincia.apply(lambda x: x.decode("utf-8"))

# %%
dataset.shape, dataset.year.dropna().shape
# Out:
# ((1439, 18), (1316,))

# %% [markdown]
# ---
# # Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# * Crear una imagen mostrando la distribución de los eventos por año
#
# * Construir una tabla de frecuencia de probabilidades dado el evento Y = ’año en el que ocurrió’
#
# $$fdp(Y)$$
#
# * Crear una imagen de dichas probabilidades con el gráfico que considere adecuado. ¿Son ambos gráficos iguales? ¿Cuál considera que es más útil?
#
# * ¿A qué se debe la forma de la distribución? ¿Qué tendencia muestra? ¿Ha aumentado la violencia institucional en los últimos años?
#
# * Calcular la función de distribución acumulada de la variable Y y graficarla. ¿Cuál es la probabilidad de que haya dado un acto de violencia antes del último cambio de gobierno?
#
# IMPORTANTE: ¿Qué hacemos con los datos faltantes?

# %% [markdown]
# Solución

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = 10, 8
import seaborn as sns

ax = sns.countplot(x="year", data=dataset)
ax.set_xticklabels(ax.get_xticklabels(), rotation=70, ha="right")
seaborn.despine()
#seaborn.countplot(dataset.year, color='#2ecc71',hue="who")
#seaborn.despine()

# %%
fdps = pandas.DataFrame(dataset.year.value_counts(normalize=True).sort_index())
fdps
# Out:
#             year
# 1988.0  0.000760
# 1989.0  0.000760
# 1990.0  0.003799
# 1991.0  0.003799
# 1993.0  0.001520
# 1994.0  0.002280
# 1996.0  0.000760
# 1997.0  0.000760
# 1998.0  0.001520
# 1999.0  0.001520
# 2000.0  0.002280
# 2001.0  0.002280
# 2002.0  0.005319
# 2003.0  0.006839
# 2004.0  0.001520
# 2005.0  0.002280
# 2006.0  0.002280
# 2007.0  0.003799
# 2008.0  0.003799
# 2009.0  0.007599
# 2010.0  0.015957
# 2011.0  0.012158
# 2012.0  0.047112
# 2013.0  0.216565
# 2014.0  0.183131
# 2015.0  0.066109
# 2016.0  0.225684
# 2017.0  0.177812

# %%
fdps.plot(kind='bar')

# %% [markdown]
# Ambos graficos son iguales salvo por la escala del eje Y, ya que uno muestra la frecuencia de ocurrencia y el otro por probabilidad.
#
# En el gráfico se muestra como crece en los últimos años las denuncias, con un decaimiento en el año 2015 que coincidió con un cambio de gobierno. Si bien es marcado el crecimiento de las denuncias en los últimos años, con esto no se puede afirmar el crecimiento de la violencia institucional, ya que puede ser que lo que haya crecido en los últimos años haya sido las posibilidades y las facilidades para denunciar.

# %%
fda = fdps.cumsum()
fda
# Out:
#             year
# 1988.0  0.000760
# 1989.0  0.001520
# 1990.0  0.005319
# 1991.0  0.009119
# 1993.0  0.010638
# 1994.0  0.012918
# 1996.0  0.013678
# 1997.0  0.014438
# 1998.0  0.015957
# 1999.0  0.017477
# 2000.0  0.019757
# 2001.0  0.022036
# 2002.0  0.027356
# 2003.0  0.034195
# 2004.0  0.035714
# 2005.0  0.037994
# 2006.0  0.040274
# 2007.0  0.044073
# 2008.0  0.047872
# 2009.0  0.055471
# 2010.0  0.071429
# 2011.0  0.083587
# 2012.0  0.130699
# 2013.0  0.347264
# 2014.0  0.530395
# 2015.0  0.596505
# 2016.0  0.822188
# 2017.0  1.000000

# %%
fda.plot(style='*')
fda[2015:2015]
# Out:
#             year
# 2015.0  0.596505

# %% [markdown]
# La probabilidad de que haya una denuncia de un acto de violencia antes del cambio del último gobierno es de 0.596505 como se observa en la tabla de probabilidades acumuladas.

# %%
#IMPORTANTE: ¿Qué hacemos con los datos faltantes?

# %% [markdown]
# ## Ejercicio 2
#
# * Construir una tabla de frecuencia de probabilidades dado el evento X = ’provincia donde se desarrollo el hecho’
#
# $$fdp(X)$$
#
# * ¿Qué información adicional es necesaria para mostrar estos datos de manera más adecuada?
# * Muestre la distribución de los eventos visualmente. ¿Qué tipo de gráfico es más adecuado para mostrar esta información?

# %% [markdown]
# Solución

# %%
fdps = pandas.DataFrame(dataset.provincia.value_counts(normalize=True).sort_index())
fdps
# Out:
#                         provincia
# Buenos Aires             0.693182
# Catamarca                0.001420
# Chaco                    0.020597
# Chubut                   0.026278
# Ciudad de Buenos Aires   0.083097
# Corrientes               0.003551
# Córdoba                  0.036932
# Entre Rios               0.006392
# Formosa                  0.007102
# Jujuy                    0.006392
# La Pampa                 0.007102
# La Rioja                 0.004261
# Mendoza                  0.012074
# Misiones                 0.007812
# Neuquen                  0.014915
# Rio Negro                0.019176
# Salta                    0.012074
# San Juan                 0.002131
# San Luis                 0.002841
# Santa Cruz               0.002841
# Santa Fe                 0.014205
# Santiago del Estero      0.007102
# Tierra del Fuego         0.001420
# Tucuman                  0.007102

# %% [markdown]
# Para tener una mejor referencia de los datos sería conveniente poder ponderarlo por la cantidad de habitantes de cada provincia.

# %%
fdps.plot(kind='bar')

# %%
#¿Qué tipo de gráfico es más adecuado para mostrar esta información?

# %% [markdown]
# ### Ejercicio 3
#
# * Construir una tabla de doble entrada donde se observen las función de distribución de probabilidades con las 2 variables aleatorias anteriores.
# ¿Son eventos independientes?
#
# * Crear una imagen de dichas probabilidades con el gráfico que considere adecuado.

# %% [markdown]
# Solución

# %%
dataset_sin_na = dataset.dropna(axis=0, subset=['year', 'provincia'])
provincias = dataset_sin_na.provincia.unique()
years = dataset_sin_na.year.unique()
serie = dataset_sin_na.groupby(['year', 'provincia']).size()/(len(dataset_sin_na))
tabla = pandas.DataFrame(serie)
tabla = tabla.reset_index(level=['year', 'provincia']).pivot(index='year', columns='provincia', values=0)
tabla = tabla.fillna(0)

tabla[10:]
# Out:
# provincia  Buenos Aires  Catamarca     Chaco    Chubut  \
# year
# 1988.0         0.000000   0.000000  0.000000  0.000000
# 1989.0         0.000766   0.000000  0.000000  0.000000
# 1990.0         0.000000   0.000000  0.003065  0.000000
# 1991.0         0.002299   0.000000  0.000000  0.000000
# 1993.0         0.000000   0.000000  0.000000  0.000000
# 1994.0         0.000766   0.000000  0.000000  0.000000
# 1996.0         0.000000   0.000000  0.000000  0.000000
# 1997.0         0.000000   0.000000  0.000000  0.000000
# 1998.0         0.000000   0.000000  0.000000  0.000000
# 1999.0         0.000000   0.000000  0.000000  0.000000
# 2000.0         0.000766   0.000000  0.000000  0.000000
# 2001.0         0.000000   0.000000  0.000000  0.000000
# 2002.0         0.003831   0.000000  0.000000  0.000000
# 2003.0         0.001533   0.000000  0.000000  0.001533
# 2004.0         0.001533   0.000000  0.000000  0.000000
# 2005.0         0.000766   0.000000  0.000000  0.000000
# 2006.0         0.000000   0.000000  0.000000  0.000000
# 2007.0         0.003065   0.000000  0.000000  0.000000
# 2008.0         0.002299   0.000000  0.000000  0.000000
# 2009.0         0.003065   0.000000  0.000000  0.000000
# 2010.0         0.006130   0.000000  0.000000  0.002299
# 2011.0         0.006897   0.000000  0.000000  0.000000
# 2012.0         0.016092   0.000000  0.005364  0.002299
# 2013.0         0.150192   0.000000  0.006130  0.004598
# 2014.0         0.125670   0.000000  0.002299  0.006897
# 2015.0         0.037548   0.000000  0.002299  0.001533
# 2016.0         0.178544   0.000766  0.002299  0.001533
# 2017.0         0.143295   0.000000  0.000766  0.005364
#
# provincia  Ciudad de Buenos Aires  Corrientes   Córdoba  Entre Rios   Formosa  \
# year
# 1988.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 1989.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 1990.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 1991.0                   0.001533    0.000000  0.000000    0.000000  0.000000
# 1993.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 1994.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 1996.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 1997.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 1998.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 1999.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 2000.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 2001.0                   0.001533    0.000000  0.000000    0.000000  0.000000
# 2002.0                   0.000000    0.000000  0.000000    0.000000  0.000766
# 2003.0                   0.001533    0.000000  0.000000    0.000000  0.000000
# 2004.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 2005.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 2006.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 2007.0                   0.000000    0.000000  0.000000    0.000000  0.000000
# 2008.0                   0.000766    0.000000  0.000000    0.000000  0.000000
# 2009.0                   0.003831    0.000000  0.000000    0.000000  0.000000
# 2010.0                   0.000766    0.000000  0.001533    0.000000  0.000000
# 2011.0                   0.001533    0.000000  0.002299    0.000000  0.000000
# 2012.0                   0.007663    0.000000  0.003065    0.000766  0.000000
# 2013.0                   0.017625    0.001533  0.003831    0.000000  0.002299
# 2014.0                   0.018391    0.000000  0.003065    0.006130  0.002299
# 2015.0                   0.007663    0.000766  0.009962    0.000000  0.000766
# 2016.0                   0.008429    0.000766  0.008429    0.000000  0.000766
# 2017.0                   0.009195    0.000000  0.007663    0.000000  0.000766
#
# provincia     Jujuy    ...      Neuquen  Rio Negro     Salta  San Juan  \
# year                   ...
# 1988.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1989.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1990.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1991.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1993.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1994.0     0.000000    ...     0.000766   0.000000  0.000000  0.000000
# 1996.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1997.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 1998.0     0.000000    ...     0.000766   0.000000  0.000000  0.000000
# 1999.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 2000.0     0.000766    ...     0.000000   0.000000  0.000000  0.000000
# 2001.0     0.000000    ...     0.000000   0.000000  0.000766  0.000000
# 2002.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 2003.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 2004.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 2005.0     0.000000    ...     0.000000   0.000766  0.000000  0.000000
# 2006.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 2007.0     0.000000    ...     0.000766   0.000000  0.000000  0.000000
# 2008.0     0.000766    ...     0.000000   0.000000  0.000000  0.000000
# 2009.0     0.000000    ...     0.000000   0.000000  0.000000  0.000000
# 2010.0     0.000766    ...     0.000000   0.000000  0.000766  0.000000
# 2011.0     0.000000    ...     0.000000   0.000766  0.000000  0.000000
# 2012.0     0.000766    ...     0.006897   0.000000  0.000000  0.000000
# 2013.0     0.000766    ...     0.003065   0.004598  0.001533  0.000000
# 2014.0     0.000766    ...     0.001533   0.005364  0.000766  0.000000
# 2015.0     0.000766    ...     0.000766   0.000000  0.000000  0.000000
# 2016.0     0.000000    ...     0.000000   0.005364  0.007663  0.002299
# 2017.0     0.000000    ...     0.000000   0.002299  0.000766  0.000000
#
# provincia  San Luis  Santa Cruz  Santa Fe  Santiago del Estero  \
# year
# 1988.0     0.000000    0.000000  0.000000             0.000000
# 1989.0     0.000000    0.000000  0.000000             0.000000
# 1990.0     0.000000    0.000000  0.000000             0.000000
# 1991.0     0.000000    0.000000  0.000000             0.000000
# 1993.0     0.001533    0.000000  0.000000             0.000000
# 1994.0     0.000000    0.000000  0.000766             0.000000
# 1996.0     0.000000    0.000000  0.000000             0.000000
# 1997.0     0.000000    0.000000  0.000000             0.000000
# 1998.0     0.000000    0.000000  0.000000             0.000000
# 1999.0     0.000000    0.000000  0.000000             0.000000
# 2000.0     0.000000    0.000000  0.000000             0.000000
# 2001.0     0.000000    0.000000  0.000000             0.000000
# 2002.0     0.000000    0.000000  0.000766             0.000000
# 2003.0     0.000000    0.000000  0.000000             0.000000
# 2004.0     0.000000    0.000000  0.000000             0.000000
# 2005.0     0.000000    0.000000  0.000000             0.000000
# 2006.0     0.000000    0.000000  0.000000             0.000000
# 2007.0     0.000000    0.000000  0.000000             0.000000
# 2008.0     0.000000    0.000000  0.000000             0.000000
# 2009.0     0.000000    0.000000  0.000000             0.000000
# 2010.0     0.000000    0.001533  0.000000             0.000000
# 2011.0     0.000000    0.000000  0.000000             0.000000
# 2012.0     0.000000    0.000000  0.000000             0.000000
# 2013.0     0.000766    0.000766  0.006130             0.002299
# 2014.0     0.000000    0.000000  0.001533             0.000766
# 2015.0     0.000000    0.000000  0.001533             0.000000
# 2016.0     0.000000    0.000766  0.000000             0.003065
# 2017.0     0.000000    0.000000  0.003831             0.001533
#
# provincia  Tierra del Fuego   Tucuman
# year
# 1988.0             0.000000  0.000000
# 1989.0             0.000000  0.000000
# 1990.0             0.000000  0.000000
# 1991.0             0.000000  0.000000
# 1993.0             0.000000  0.000000
# 1994.0             0.000000  0.000000
# 1996.0             0.000000  0.000000
# 1997.0             0.000000  0.000000
# 1998.0             0.000000  0.000000
# 1999.0             0.000000  0.000000
# 2000.0             0.000000  0.000000
# 2001.0             0.000000  0.000000
# 2002.0             0.000000  0.000000
# 2003.0             0.000000  0.000000
# 2004.0             0.000000  0.000000
# 2005.0             0.000000  0.000000
# 2006.0             0.000766  0.000000
# 2007.0             0.000000  0.000000
# 2008.0             0.000000  0.000000
# 2009.0             0.000766  0.000000
# 2010.0             0.000000  0.000000
# 2011.0             0.000000  0.000000
# 2012.0             0.000000  0.001533
# 2013.0             0.000000  0.000000
# 2014.0             0.000000  0.000000
# 2015.0             0.000000  0.001533
# 2016.0             0.000000  0.002299
# 2017.0             0.000000  0.001533
#
# [28 rows x 24 columns]

# %%
criterio = 0.05  #me parece mas razonable

def son_independientes(tabla):
    for provincia in provincias:
        for year in years:
            if abs(tabla.loc[year, provincia] - tabla.loc[year].sum()*tabla[provincia].sum()) > criterio:
                return 'No son independientes'
    return "Son independientes"

son_independientes(tabla)
# Out:
# 'Son independientes'

# %%
from matplotlib.colors import LogNorm

seaborn.heatmap(tabla + 0.0000001, linewidths=0, cmap='Reds', norm=LogNorm(0.0000001, 1))

# %%
import numpy 
import matplotlib
matplotlib.rcParams['figure.figsize'] = 10, 8

#con el unique, la longitud de x e y son distintas!
provincias = dataset_sin_na.provincia
years = dataset_sin_na.year
prob_conjunta = dataset_sin_na.groupby('year')['provincia'].value_counts()
colors = numpy.random.rand(1305)
matplotlib.pyplot.scatter(years,provincias,s=prob_conjunta,c=colors, alpha=0.5)

# %% [markdown]
# ## Ejercicio 4
#
# Dada la variable aleatoria Z = ’contexto1 en el que se produjo el hecho’, calcular la probabilidad que el hecho sea producido en una dependencia de una fuerza de seguridad (penal, comisaría, etc)
#
# $$ fdp(z=penal ~~ |~~  z=comisaria ~~ | ...) $$

# %% [markdown]
# Solución

# %%
z = dataset.contexto1 
fdps_z = pandas.DataFrame(z.value_counts(normalize=True).sort_index())
fdps_z.plot(style='v')
fdps_z
# Out:
#                                                     contexto1
# Centros de Alojamiento para Personas Menores de...   0.001444
# Centros de Detención Preventiva                      0.004332
# Centros de Detención Previos al Juicio (Alcaidia)    0.011552
# Comisaría                                            0.091697
# Domicilio Particular                                 0.016606
# Escuelas de Formación Fuerzas Nacionales             0.000722
# Escuelas de Formación Fuerzas Provinciales           0.002166
# Espacio Público                                      0.153069
# Establecimiento de Rehabilitación de Adicciones      0.000722
# Establecimiento de Salud Mental                      0.005054
# Hospital General                                     0.003610
# Instalaciones de la Gendarmería Nacional             0.002888
# Instalaciones de las Fuerzas Armadas (cuarteles...   0.001444
# Lugar No Identificado                                0.008664
# Móviles y medios de transporte de Fuerzas de Se...   0.009386
# Penal / Complejo Penitenciario FEDERAL               0.321300
# Penal / Complejo Penitenciario PROVINCIAL            0.365343

# %%
#Me parece q da para hacer algun comentario al respecto

# %% [markdown]
# ## Ejercicio 5
#
# Dada la variable aleatoria M = ‘existió violencia fisica’:
# * ¿Que probabilidad existe que también tenga violencia psíquica? N = ‘existió violencia psíquica’
#
# $$P(M~~|~~N)$$
#
# * ¿Qué conclusión se puede formular de los datos que tenemos y los datos que obtenemos de los métodos probabilísticos?
# * ¿Podemos concluir en que son eventos independientes dadas las muestras?

# %% [markdown]
# Solución

# %%
dataset_sin_na = dataset.dropna(axis=0, subset=['violencia_psiquica', 'violencia_fisica'])
M = dataset_sin_na.violencia_fisica.unique()
N = dataset_sin_na.violencia_psiquica.unique()
p_M_N = dataset_sin_na.groupby(['violencia_fisica','violencia_psiquica']).size() / dataset_sin_na.groupby('violencia_fisica')['violencia_psiquica'].count()

# %%
#¿Qué conclusión se puede formular de los datos que tenemos 
#y los datos que obtenemos de los métodos probabilísticos?

# %%
#tabla = pandas.DataFrame(p_M_N)
#tabla = tabla.reset_index(level=['violencia_fisica', 'violencia_psiquica']).pivot(index='violencia_fisica', columns='violencia_psiquica', values=0)
#tabla = tabla.fillna(0)
#tabla

#criterio = 0.05          #Generalmente el porcentaje de errar a su hp que el autor del estudio
                         #estadistico que está dispuesto a cometer es de 5%.

#def son_independientes(tabla):
 #   for violencia_fisica in M:
  #      for violencia_psiquica in N:
   #         if abs(tabla.loc[violencia_fisica, violencia_psiquica] - tabla.loc[violencia_psiquica].sum()) > criterio:
    #            return 'No son independientes'
    #return "Son independientes"

#son_independientes(tabla)
